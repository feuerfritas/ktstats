# %%
from ktstats import KtRoll
import lea
from ktstats import Weapon
from ktstats import Target
from ktstats import WeaponDamageProfile
from ktstats import plot_heatmap

# %%
heavy_stubber = Weapon('Heavy Stubber', 5, 4, 3, 4, ['Ceaseless', 'Fussillade', 'Heavy'])
plot_heatmap(heavy_stubber)

# %%
grenade_launcher = Weapon('Grenade Launcher', 4, 4, 4, 6, ['AP1'])
plot_heatmap(grenade_launcher)

# %%
webber = Weapon('Webber', 5, 3, 2, 2, ['Lethal 5+', 'Stun', 'RNG 6'])
plot_heatmap(webber)

# %%
exec_shotgun = Weapon('Executionar Shotgun', 4, 3, 4, 1, ['Heavy', 'Silent', 'MW3'])
plot_heatmap(exec_shotgun)

# %%
combat_shotgun = Weapon('Combat Shotgun - Close Range', 4, 3, 4, 4, ['RNG 6'])
plot_heatmap(combat_shotgun)

# %%
combat_shotgun_l = Weapon('Combat Shotgun - Long Range', 4, 5, 2, 2, [])
plot_heatmap(combat_shotgun_l)

# %%
plot_heatmap(Weapon('Scoped Shotpistol', 4, 3, 3, 1, ['MW2']))

# %%
plot_heatmap(Weapon('Shotpistol - 1EP', 4, 4, 3, 3, ['RNG 6']))

# %%
plot_heatmap(Weapon('Frag Grenade - 2EP?', 4, 3, 2, 3, ['RNG 6', 'Indirect', 'Limited', 'Blast 2']))

# %%
plot_heatmap(Weapon('Krak Grenade - 3EP?', 4, 3, 4, 5, ['RNG 6', 'Indirect', 'Limited', 'AP1']))

# %%
from ktstats import Fight
from ktstats import Target
from ktstats import MeleeWeapon
from ktstats import print_combat_results

fight = Fight(
    Target(3,4, wounds=8, name='Proctor Exactant'),
    MeleeWeapon('Dominator Maul', 4, 3, 4, 4, ['Lethal 5+', 'Stun']),
    Target(3,4, wounds=7, name='Trooper Veteran'),
    MeleeWeapon('Bayonet', 3, 4, 2, 3, [])
)

print_combat_results(fight)
# Out:
# Combat Results:
# --------------
# attacker rerolls: 1
#
# defender rerolls: 1
#
# Survibability:
#
# (D) Trooper Veteran dead - (A) Proctor Exactant survives     :  81.19 % ---------------------------------------------------------------------------------
# (D) Trooper Veteran survives - (A) Proctor Exactant dead     :   0.06 %
# (D) Trooper Veteran survives - (A) Proctor Exactant survives :  18.75 % -------------------
#
# Operative state:
#
# (D) Trooper Veteran dead - (A) Proctor Exactant injured        :   4.13 % ----
# (D) Trooper Veteran dead - (A) Proctor Exactant survives       :  71.10 % -----------------------------------------------------------------------
# (D) Trooper Veteran dead - (A) Proctor Exactant untouched      :   5.97 % ------
# (D) Trooper Veteran survives - (A) Proctor Exactant dead       :   0.02 %
# (D) Trooper Veteran survives - (A) Proctor Exactant injured    :   4.81 % -----
# ...
