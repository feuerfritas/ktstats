# %%
from ktstats import plot_heatmap

# %%
plot_heatmap(Weapon('Blast Pistol', 4, 3, 4, 5, ['RNG 6', 'AP2']))

# %%
plot_heatmap(Weapon('Splinter Rifle', 4, 3, 2, 4, ['Lethal 5+']))

# %%
plot_heatmap(Weapon('Splinter Rifle - Refined Poison 2EP', 4, 3, 3, 4, ['Lethal 5+']))

# %%
plot_heatmap(Weapon('Splinter Pistol - Leader', 4, 2, 2, 4, ['RNG 6', 'Lethal 5+']))

# %%
plot_heatmap(Weapon('Splinter Pistol - Leader - Refined Poison 2EP', 4, 2, 3, 4, ['RNG 6', 'Lethal 5+']))

# %%
plot_heatmap(Weapon('Splinter Rifle - Leader', 4, 2, 2, 4, ['Lethal 5+']))

# %%
plot_heatmap(Weapon('Splinter Rifle - Leader - Refined Poison 2EP', 4, 2, 3, 4, ['Lethal 5+']))

# %%
plot_heatmap(Weapon('Splinter Rifle', 4, 3, 2, 4, ['Lethal 5+']))

# %%
plot_heatmap(Weapon('Splinter Rifle - Refined Poison 2EP', 4, 3, 3, 4, ['Lethal 5+']))

# %%
plot_heatmap(Weapon('Blaster', 4, 3, 5, 6, ['AP2']))

# %%
plot_heatmap(Weapon('Shredder', 5, 3, 3, 4, ['Blast 2', 'Rending']))

# %%
plot_heatmap(Weapon('Dark Lance', 4, 3, 6, 7, ['AP2', 'Heavy', 'Unwieldy']))

# %%
plot_heatmap(Weapon('Splinter Cannon', 5, 3, 3, 5, ['Fussilade', 'Heavy', 'Lethal 5+']))

# %%
plot_heatmap(Weapon('Splinter Cannon - Refined Poison 3EP', 5, 3, 4, 5, ['Fussilade', 'Heavy', 'Lethal 5+']))

# %%
plot_heatmap(Weapon('Stinger Pistol - aprox', 5, 2, 1, 0, ['MW3', 'Stinger']))

# %%
plot_heatmap(Weapon('Stinger Rifle', 4, 3, 2, 4, ['Lethal 5+']))

# %%
plot_heatmap(Weapon('Razorwing', 5, 4, 1, 2, ['Indirect', 'No Cover', 'Silent']))

# %%
plot_heatmap(Weapon('Shardcarbine', 4, 3, 2, 2, ['Ceaseless', 'Lethal 5+', 'MW2']))

# %%
plot_heatmap(Weapon('Shardcarbine - Refined Poison 3EP', 4, 3, 3, 2, ['Ceaseless', 'Lethal 5+', 'MW2']))
